# %% [markdown]
# # FashionMNIST 데이터 로딩 및 시각화

# %% [markdown]
# ## 1. 라이브러리 불러오기

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from data_loader import get_loaders

# %% [markdown]
# ## 2. 데이터셋 및 DataLoader 구성
# - `data_loader.py` 모듈 불러오기

# %%
train_loader, test_loader = get_loaders(batch_size=64)

# %% [markdown]
# ## 3. 라벨 이름 매핑

# %%
labels_map={
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %% [markdown]
# ## 4. 샘플 이미지 시각화

# %%
figure = plt.figure(figsize=(10, 5))
for i in range(10):
    img, label = train_dataset[i]             # i번째 샘플과 라벨
    figure.add_subplot(2, 5, i + 1)           # 2행 5열로 이미지 배치
    plt.title(labels_map[label])              # 의류 이름을 제목으로 출력
    plt.axis("off")                           # 눈금 제거
    plt.imshow(img.squeeze(), cmap="gray")    # 이미지 표시
plt.suptitle("FashionMNIST Sample Images")
plt.show()
